# %% [markdown]
# <a href="https://colab.research.google.com/github/omvaidya1/specialtask_omvaidya1/blob/main/specialtask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-77a58f8f-07ed-49de-a556-4089893a8071" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77a58f8f-07ed-49de-a556-4089893a8071">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath='/content/pokemon1.csv'
df=pd.read_csv(filepath)
df
# Out:
#          id                      name  base_experience  height  weight  \
# 0         1                 bulbasaur               64       7      69
# 1         2                   ivysaur              142      10     130
# 2         3                  venusaur              236      20    1000
# 3         4                charmander               62       6      85
# 4         5                charmeleon              142      11     190
# ...     ...                       ...              ...     ...     ...
# 1297  10273   ogerpon-wellspring-mask              275      12     398
# 1298  10274  ogerpon-hearthflame-mask              275      12     398
# 1299  10275  ogerpon-cornerstone-mask              275      12     398
# 1300  10276        terapagos-terastal               90       3     160
# 1301  10277         terapagos-stellar               90      17     770
#
#               types              abilities  \
# 0     grass, poison  overgrow, chlorophyll
# ...

# %%
df.head()
# Out:
#    id        name  base_experience  height  weight          types  \
# 0   1   bulbasaur               64       7      69  grass, poison
# 1   2     ivysaur              142      10     130  grass, poison
# 2   3    venusaur              236      20    1000  grass, poison
# 3   4  charmander               62       6      85           fire
# 4   5  charmeleon              142      11     190           fire
#
#                abilities                                              moves  \
# 0  overgrow, chlorophyll     razor-wind, swords-dance, cut, bind, vine-whip
# 1  overgrow, chlorophyll       swords-dance, cut, bind, vine-whip, headbutt
# 2  overgrow, chlorophyll       swords-dance, cut, bind, vine-whip, headbutt
# 3     blaze, solar-power  mega-punch, fire-punch, thunder-punch, scratch...
# 4     blaze, solar-power  mega-punch, fire-punch, thunder-punch, scratch...
#
#                                                stats
# 0  hp=45, attack=49, defense=49, special-attack=6...
# ...

# %%
df.tail()
# Out:
#          id                      name  base_experience  height  weight  \
# 1297  10273   ogerpon-wellspring-mask              275      12     398
# 1298  10274  ogerpon-hearthflame-mask              275      12     398
# 1299  10275  ogerpon-cornerstone-mask              275      12     398
# 1300  10276        terapagos-terastal               90       3     160
# 1301  10277         terapagos-stellar               90      17     770
#
#              types      abilities  \
# 1297  grass, water   water-absorb
# 1298   grass, fire   mold-breaker
# 1299   grass, rock         sturdy
# 1300        normal     tera-shell
# 1301        normal  teraform-zero
#
#                                                   moves  \
# 1297  swords-dance, slam, vine-whip, double-kick, ta...
# 1298  swords-dance, slam, vine-whip, double-kick, ta...
# 1299  swords-dance, slam, vine-whip, double-kick, ta...
# 1300  headbutt, body-slam, take-down, double-edge, roar
# ...

# %%
df.shape
# Out:
# (1302, 9)

# %%
df.columns
# Out:
# Index(['id', 'name', 'base_experience', 'height', 'weight', 'types',
#        'abilities', 'moves', 'stats'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1302 non-null   int64
#  1   name             1302 non-null   object
#  2   base_experience  1302 non-null   int64
#  3   height           1302 non-null   int64
#  4   weight           1302 non-null   int64
#  5   types            1302 non-null   object
#  6   abilities        1302 non-null   object
#  7   moves            1268 non-null   object
#  8   stats            1302 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 91.7+ KB

# %%
df.describe()
# Out:
#                  id  base_experience       height        weight
# count   1302.000000      1302.000000  1302.000000   1302.000000
# mean    2560.927803       161.943932    20.467742    980.863287
# std     3949.887748        82.532554    54.180316   1972.645170
# min        1.000000        36.000000     1.000000      0.000000
# 25%      326.250000        71.000000     5.000000     89.250000
# 50%      651.500000       165.000000    10.000000    315.500000
# 75%      976.750000       222.500000    16.000000    818.000000
# max    10277.000000       608.000000  1000.000000  10000.000000

# %%
df.dtypes
# Out:
# id                  int64
# name               object
# base_experience     int64
# height              int64
# weight              int64
# types              object
# abilities          object
# moves              object
# stats              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                  0
# name                0
# base_experience     0
# height              0
# weight              0
# types               0
# abilities           0
# moves              34
# stats               0
# dtype: int64

# %%
df.nunique()
# Out:
# id                 1302
# name               1302
# base_experience     201
# height               85
# weight              533
# types               221
# abilities           707
# moves               812
# stats              1142
# dtype: int64

# %%
df.sample(5)
# Out:
#       id       name  base_experience  height  weight           types  \
# 731  732   trumbeak              124       6     148  normal, flying
# 252  253    grovyle              142       9     216           grass
# 273  274    nuzleaf              119      10     280     grass, dark
# 182  183     marill               88       4      85    water, fairy
# 449  450  hippowdon              184      20    3000          ground
#
#                                abilities  \
# 731         keen-eye, skill-link, pickup
# 252                   overgrow, unburden
# 273  chlorophyll, early-bird, pickpocket
# 182    thick-fat, huge-power, sap-sipper
# 449              sand-stream, sand-force
#
#                                                  moves  \
# 731   swords-dance, fly, fury-attack, take-down, growl
# 252  pound, mega-punch, thunder-punch, swords-dance...
# 273    pound, razor-wind, swords-dance, cut, mega-kick
# 182   mega-punch, ice-punch, slam, mega-kick, headbutt
# ...

# %%
df.value_counts()
# Out:
# id     name                         base_experience  height  weight  types           abilities                        moves                                                         stats
# 10277  terapagos-stellar            90               17      770     normal          teraform-zero                    headbutt, body-slam, take-down, double-edge, roar             hp=160, attack=105, defense=110, special-attack=130, special-defense=110, speed=85    1
# 1      bulbasaur                    64               7       69      grass, poison   overgrow, chlorophyll            razor-wind, swords-dance, cut, bind, vine-whip                hp=45, attack=49, defense=49, special-attack=65, special-defense=65, speed=45         1
# 2      ivysaur                      142              10      130     grass, poison   overgrow, chlorophyll            swords-dance, cut, bind, vine-whip, headbutt                  hp=60, attack=62, defense=63, special-attack=80, special-defense=80, speed=60         1
# ...
